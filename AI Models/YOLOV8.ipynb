# %%
#change runtime to T4 GPU
# !nvidia-smi
# Out:
# Sun Nov 19 18:08:44 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#For YOLOV8 we need to install ultralytics
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 9.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from IPython.display import display,Image

# %%
# detection, segmentation and classification can be done in YOLO
#here we are detecting

# !yolo task=detect mode = predict model =yolov8n.pt conf =0.25 source="https://production-media.paperswithcode.com/thumbnails/task/task-0000000745-802706d9.jpg"
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 23.0MB/s]
# Ultralytics YOLOv8.0.212 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 22.4k/22.4k [00:00<00:00, 25.7MB/s]
# image 1/1 /content/task-0000000745-802706d9.jpg: 384x640 8 cars, 1 bus, 91.8ms
# Speed: 13.6ms preprocess, 91.8ms inference, 41.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='/content/runs/detect/predict/task-0000000745-802706d9.jpg')

# %%
# segmentation

# !yolo task=segment mode=predict model=yolov8n-seg.pt conf=0.25 source='https://img.freepik.com/premium-vector/vector-set-realistic-colorful-empty-shopping-bags-promotion-isolated-white-background_572288-732.jpg'
# Out:
# ...
# 100% 6.73M/6.73M [00:00<00:00, 24.3MB/s]
# Ultralytics YOLOv8.0.212 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients, 12.6 GFLOPs
#
# ...
# 100% 31.2k/31.2k [00:00<00:00, 10.8MB/s]
# image 1/1 /content/vector-set-realistic-colorful-empty-shopping-bags-promotion-isolated-white-background_572288-732.jpg: 512x640 3 refrigerators, 142.9ms
# Speed: 5.9ms preprocess, 142.9ms inference, 10.4ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='/content/runs/segment/predict/vector-set-realistic-colorful-empty-shopping-bags-promotion-isolated-white-background_572288-732.jpg')

# %%
# classify

# !yolo task=classify mode=predict model=yolov8n-cls.pt conf=0.25 source="https://production-media.paperswithcode.com/thumbnails/task/task-0000000745-802706d9.jpg"
# Out:
# ...
# 100% 5.28M/5.28M [00:00<00:00, 20.6MB/s]
# Ultralytics YOLOv8.0.212 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients, 4.3 GFLOPs
#
# Found https://production-media.paperswithcode.com/thumbnails/task/task-0000000745-802706d9.jpg locally at task-0000000745-802706d9.jpg
# ...
# 100% 755k/755k [00:00<00:00, 4.59MB/s]
# image 1/1 /content/task-0000000745-802706d9.jpg: 224x224 forklift 0.20, dock 0.08, container_ship 0.07, crane_(machine) 0.06, tow_truck 0.04, 4.5ms
# Speed: 8.2ms preprocess, 4.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename ="/content/runs/classify/predict/task-0000000745-802706d9.jpg")

# %% [markdown]
# #For training custom dataset

# %%
##    !yolo task=detect mode=train model=yolov8l.pt data =/content/plastics-3/data.yaml epochs=50 imgsz=640
